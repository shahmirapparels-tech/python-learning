# %% [markdown]
# # Variables + print() Q1

# %% [markdown]
# name= "Hasnain"
# age = "15"
# institute = "hajiyani"
#
# print (name)
#
# print (age)
#
# print (institute)

# %% [markdown]
# #  input() Function Q2

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
city = input("Enter your city: ")
course = input("Enter your course: ")

print (name,age,city,course)
# Out:
# Enter your name:  Hasnain
# Enter your age:  15
# Enter your city:  Karachi
# Enter your course:  AI AND DS
# Hasnain 15  Karachi AI AND DS

# %% [markdown]
# # int(), float(), str()

# %%
birth_year = int(input("Enter your birth year:"))
current_year = 2026
age = birth_year - current_year
print ("Your approximate age is: ",age)
# Out:
# Enter your birth year: 2010
# Your approximate age is:  -16

# %% [markdown]
# # String Concatenation

# %%
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
full_name = (first_name +"" + last_name)
print (full_name)
# Out:
# Enter your first name:  Hasnain
# Enter your last name:  Aamir
# HasnainAamir

# %% [markdown]
# # String Repetition

# %%
name = "Hasnain Aamir"
print ((name + "\n") * 10)
# Out:
# Hasnain Aamir
# Hasnain Aamir
# Hasnain Aamir
# Hasnain Aamir
# Hasnain Aamir
# Hasnain Aamir
# Hasnain Aamir
# Hasnain Aamir
# Hasnain Aamir
# Hasnain Aamir

# %% [markdown]
# # Arithmetic Operators

# %%
num1 = 10
num2 = 6

print ("addition" , num1 + num2)
print ("subtraction" , num1 - num2)
print ("multiplication" , num1 * num2)
print ("division" , num1 / num2)
print ("modulus" , num1 % num2)
# Out:
# addition 16
# subtraction 4
# multiplication 60
# division 1.6666666666666667
# modulus 4

# %% [markdown]
# # logical operator

# %%
True or True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
True or Flase
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# # in

# %% [markdown]
# email= input("enter your email")
#
# print("@" in email)

# %% [markdown]
# # decision making struction
# 1 if-else
# 2 if-elif-

# %%
age = 18
if age>= 18:
 print("ADULT")
else:
    print("teenager")
# Out:
# ADULT
