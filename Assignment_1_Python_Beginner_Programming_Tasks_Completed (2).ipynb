# %% [markdown]
# ## Question 1
#
# 1. Student Information — Store name, age, course, and institute in variables. Display them using print().

# %%
name = "shahmir imran"
age = 22
course = "Python Programming"
institute = "Saylani Mass IT Training"

print("Name:", name)
print("Age:", age)
print("Course:", course)
print("Institute:", institute)
# Out:
# Name: shahmir imran
# Age: 22
# Course: Python Programming
# Institute: Saylani Mass IT Training

# %% [markdown]
# ## Question 2
#
# 2. Employee Information — Store employee name, department, salary, and experience. Print a simple employee profile.

# %%
employee_name = "Bilal Ahmed"
department = "Finance"
salary = 65000
experience = 3

print("Employee Name:", employee_name)
print("Department:", department)
print("Salary:", salary)
print("Experience:", experience, "years")
# Out:
# Employee Name: Bilal Ahmed
# Department: Finance
# Salary: 65000
# Experience: 3 years

# %% [markdown]
# ## Question 3
#
# 3. Product Information — Store product name, price, and quantity. Display all information.

# %%
product_name = "Ladies Lawn Suit"
price = 2500
quantity = 3

print("Product Name:", product_name)
print("Price:", price)
print("Quantity:", quantity)
# Out:
# Product Name: Ladies Lawn Suit
# Price: 2500
# Quantity: 3

# %% [markdown]
# ## Question 4
#
# 4. Personal Introduction — Ask the user for name, age, city, and course. Print a sentence introducing the student.

# %%
name = "shahmir"
age = 22
city = "Karachi"
course = "Python Programming"

print("My name is " + name + ", I am " + str(age) + " years old, I live in " + city + ", and I am studying " + course + ".")
# Out:
# My name is shahmir, I am 22 years old, I live in Karachi, and I am studying Python Programming.

# %% [markdown]
# ## Question 5
#
# 5. Simple Greeting — Ask for the user's name and print a welcome message.

# %%
name = "shahmir"

print("Welcome, " + name + "!")
# Out:
# Welcome, shahmir!

# %% [markdown]
# ## Question 6
#
# 6. Student Registration — Ask for name, roll number, course, and semester. Display the entered information.

# %%
name = "shahmir"
roll_number = "874347"
course = "Python Programming"
semester = "1st"

print("Student Registration")
print("Name:", name)
print("Roll Number:", roll_number)
print("Course:", course)
print("Semester:", semester)
# Out:
# Student Registration
# Name: shahmir
# Roll Number: 874347
# Course: Python Programming
# Semester: 1st

# %% [markdown]
# ## Question 7
#
# 7. Age Calculator — Input birth year, convert it to int, and calculate approximate age.

# %%
birth_year = int("2004")
current_year = 2026
age = current_year - birth_year

print("Birth Year:", birth_year)
print("Current Year:", current_year)
print("Your approximate age is:", age)
# Out:
# Birth Year: 2004
# Current Year: 2026
# Your approximate age is: 22

# %% [markdown]
# ## Question 8
#
# 8. Shopping Bill — Input product price and quantity. Convert price to float and quantity to int. Calculate the total bill.

# %%
price = float("1250.50")
quantity = int("4")

total_bill = price * quantity

print("Product Price:", price)
print("Quantity:", quantity)
print("Total Bill:", total_bill)
# Out:
# Product Price: 1250.5
# Quantity: 4
# Total Bill: 5002.0

# %% [markdown]
# ## Question 9
#
# 9. Temperature Converter — Input Celsius temperature as float and convert it to Fahrenheit.

# %%
celsius = float("30")
fahrenheit = (celsius * 9 / 5) + 32

print("Celsius:", celsius)
print("Fahrenheit:", fahrenheit)
# Out:
# Celsius: 30.0
# Fahrenheit: 86.0

# %% [markdown]
# ## Question 10
#
# 10. Student Marks — Input marks of three subjects, convert them to float, and calculate total and average.

# %%
marks1 = float("78")
marks2 = float("85")
marks3 = float("72")

total = marks1 + marks2 + marks3
average = total / 3

print("Subject 1:", marks1)
print("Subject 2:", marks2)
print("Subject 3:", marks3)
print("Total Marks:", total)
print("Average Marks:", average)
# Out:
# Subject 1: 78.0
# Subject 2: 85.0
# Subject 3: 72.0
# Total Marks: 235.0
# Average Marks: 78.33333333333333

# %% [markdown]
# ## Question 11
#
# 11. Full Name Generator — Input first name and last name and combine them using +.

# %%
first_name = "Ahsan"
last_name = "Raja"

full_name = first_name + " " + last_name

print("Full Name:", full_name)
# Out:
# Full Name: Ahsan Raja

# %% [markdown]
# ## Question 12
# gmail

# %%
gmail = ("Enter your gmail")
print("@",gmail)
# Out:
# @ Enter your gmail

# %% [markdown]
# ## Question 13
#
# 13. Address Generator — Input house number, street, and city and combine them into one address.

# %%
house_number = "24"
street = "PECHS Block 2"
city = "Karachi"

address = house_number + ", " + street + ", " + city

print("Address:", address)
# Out:
# Address: 24, PECHS Block 2, Karachi

# %% [markdown]
# ## Question 14
#
# 14. Pattern Generator — Ask the user for a symbol and number, then generate a repeated pattern.

# %%
symbol = "*"
number = 8

pattern = symbol * number

print("Pattern:", pattern)
# Out:
# Pattern: ********

# %% [markdown]
# ## Question 15
#
# 15. Basic Calculator — Input two numbers and calculate addition, subtraction, multiplication, division, and modulus.

# %%
num1 = 25
num2 = 4

print("First Number:", num1)
print("Second Number:", num2)
print("Addition:", num1 + num2)
print("Subtraction:", num1 - num2)
print("Multiplication:", num1 * num2)
print("Division:", num1 / num2)
print("Modulus:", num1 % num2)
# Out:
# First Number: 25
# Second Number: 4
# Addition: 29
# Subtraction: 21
# Multiplication: 100
# Division: 6.25
# Modulus: 1

# %% [markdown]
# ## Question 16
#
# 16. Rectangle Calculator — Input length and width and calculate area and perimeter.

# %%
length = 12
width = 5

area = length * width
perimeter = 2 * (length + width)

print("Length:", length)
print("Width:", width)
print("Area:", area)
print("Perimeter:", perimeter)
# Out:
# Length: 12
# Width: 5
# Area: 60
# Perimeter: 34

# %% [markdown]
# ## Question 17
#
# 17. Circle Calculator — Input radius and calculate area and circumference.

# %%
radius = 7

pi = 3.14
area = pi * radius ** 2
circumference = 2 * pi * radius

print("Radius:", radius)
print("Area:", area)
print("Circumference:", circumference)
# Out:
# Radius: 7
# Area: 153.86
# Circumference: 43.96

# %% [markdown]
# ## Question 18
#
# 18. Simple Interest — Input principal, rate, and time and calculate simple interest.

# %%
principal = 50000
rate = 8
time = 2

simple_interest = (principal * rate * time) / 100

print("Principal:", principal)
print("Rate:", rate, "%")
print("Time:", time, "years")
print("Simple Interest:", simple_interest)
# Out:
# Principal: 50000
# Rate: 8 %
# Time: 2 years
# Simple Interest: 8000.0

# %% [markdown]
# ## Question 19
#
# 19. Shopping Calculator — Input price and quantity and calculate subtotal, discount, and final price.

# %%
price = 2000
quantity = 3
discount_rate = 10

subtotal = price * quantity
discount = subtotal * discount_rate / 100
final_price = subtotal - discount

print("Price:", price)
print("Quantity:", quantity)
print("Subtotal:", subtotal)
print("Discount:", discount)
print("Final Price:", final_price)
# Out:
# Price: 2000
# Quantity: 3
# Subtotal: 6000
# Discount: 600.0
# Final Price: 5400.0

# %% [markdown]
# ## Question 20
#
# 20. Age Eligibility — Input age and check whether the person is 18 or older.

# %%
age = 22

print("Age:", age)
print("18 or older:", age >= 18)
# Out:
# Age: 22
# 18 or older: True

# %% [markdown]
# ## Question 21
#
# 21. Pass/Fail Checker — Input marks and check whether marks are greater than or equal to 50.

# %%
marks = 67

print("Marks:", marks)
print("Passed:", marks >= 50)
# Out:
# Marks: 67
# Passed: True

# %% [markdown]
# ## Question 22
#
# 22. Driving Eligibility — Input age and whether the person has a license. Check whether age is at least 18 AND the person has a license.

# %%
age = 22
has_license = True

eligible = age >= 18 and has_license

print("Age:", age)
print("Has License:", has_license)
print("Driving Eligibility:", eligible)
# Out:
# Age: 22
# Has License: True
# Driving Eligibility: True

# %% [markdown]
# ## Question 23
#
# 23. University Admission — Input marks and age. Admission is allowed if marks are at least 50 AND age is at least 18.

# %%
marks = 72
age = 22

admission_allowed = marks >= 50 and age >= 18

print("Marks:", marks)
print("Age:", age)
print("University Admission Allowed:", admission_allowed)
# Out:
# Marks: 72
# Age: 22
# University Admission Allowed: True

# %% [markdown]
# ## Question 24
#
# 24. Discount Eligibility — A customer gets a discount if purchase amount is at least 5000 OR the customer is a member.

# %%
purchase_amount = 4500
is_member = True

discount_eligible = purchase_amount >= 5000 or is_member

print("Purchase Amount:", purchase_amount)
print("Is Member:", is_member)
print("Discount Eligibility:", discount_eligible)
# Out:
# Purchase Amount: 4500
# Is Member: True
# Discount Eligibility: True

# %% [markdown]
# ## Question 25
#
# 25. Login System — Input username and password and check whether both are correct using the and operator.

# %%
username = "admin"
password = "12345"

correct_username = "admin"
correct_password = "12345"

login_success = username == correct_username and password == correct_password

print("Username:", username)
print("Login Successful:", login_success)
# Out:
# Username: admin
# Login Successful: True

# %% [markdown]
# ## Question 26
#
# 26. Character Checker — Input a word and a character. Check whether the character exists in the word.

# %%
word = "programming"
character = "g"

print("Word:", word)
print("Character:", character)
print("Character exists:", character in word)
# Out:
# Word: programming
# Character: g
# Character exists: True

# %% [markdown]
# ## Question 27
#
# 27. Email Validator — Basic — Input an email and check whether @ exists in it.

# %%
email = "ahsan.raja@gmail.com"

print("Email:", email)
print("Valid basic email:", "@" in email)
# Out:
# Email: ahsan.raja@gmail.com
# Valid basic email: True

# %% [markdown]
# ## Question 28
#
# 28. Keyword Checker — Input a sentence and check whether the word python exists in the sentence.

# %%
sentence = "I am learning Python programming."

print("Sentence:", sentence)
print("Python exists in sentence:", "python" in sentence.lower())
# Out:
# Sentence: I am learning Python programming.
# Python exists in sentence: True
